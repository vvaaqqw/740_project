# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ### Bitcoin

# %%
selected = pd.read_csv("../Data/train_btc_selected_features.csv")
btc = pd.read_csv("../Data/btc_Data.csv")
btc['Date'] = pd.to_datetime(btc['Date'])

btc = btc.set_index("Date")

# %%
btcData = btc[selected.columns]

# %%
btc_val_set = btcData["2020-01-01":"2021-05-31"]
btc_test_set = btcData["2021-06-01":"2023-11-01"]

# %%
btc_val_set
# Out:
#             difficulty14mom  difficulty30mom  difficulty3rsi  difficulty90mom  \
# Date
# 2020-01-01     1.548159e+11     5.842203e+10          99.997     2.718386e+11
# 2020-01-02     9.059462e+11     8.255479e+11         100.000     1.038964e+12
# 2020-01-03     8.501904e+11     8.255479e+11         100.000     1.038964e+12
# 2020-01-04     8.501904e+11     8.428323e+11         100.000     1.038964e+12
# 2020-01-05     8.501904e+11     9.219417e+11         100.000     1.038964e+12
# ...                     ...              ...             ...              ...
# 2021-05-27     1.819158e+12     1.464506e+12          99.402     3.322353e+12
# 2021-05-28    -2.000000e-02     1.464506e+12          99.402     3.322353e+12
# 2021-05-29    -8.000000e-03     1.464506e+12          99.402     3.322353e+12
# 2021-05-30    -3.832142e+12    -2.367636e+12           0.141    -5.097895e+11
# 2021-05-31    -3.998757e+12    -1.956735e+12           0.133    -6.764043e+11
#
# ...

# %%
btc_test_set
# Out:
#             difficulty14mom  difficulty30mom  difficulty3rsi  difficulty90mom  \
# Date
# 2021-06-01    -3.998757e+12     4.388848e+11           0.133    -6.764043e+11
# 2021-06-02    -3.998757e+12     4.388848e+11           0.133    -6.764043e+11
# 2021-06-03    -3.998757e+12     4.388848e+11           0.133    -6.764043e+11
# 2021-06-04    -3.998757e+12     4.388848e+11           0.133    -4.259551e+11
# 2021-06-05    -3.998757e+12     4.388848e+11           0.133    -4.005472e+11
# ...                     ...              ...             ...              ...
# 2022-11-24     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-25     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-26     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-27     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-28     1.882952e+11     1.148115e+11          99.860     8.598887e+12
#
# ...

# %% [markdown]
# ### Etherium

# %%
selected = pd.read_csv("../Data/train_eth_selected_features.csv")
eth = pd.read_csv("../Data/ethereum_Data.csv")
eth['Date'] = pd.to_datetime(eth['Date'])

eth = eth.set_index("Date")
ethData = eth[selected.columns]
eth_val_set = ethData["2020-01-01":"2021-05-31"]
eth_test_set = ethData["2021-06-01":"2023-11-01"]

# %%
eth_val_set
# Out:
#             activeaddresses90roc  confirmationtime  confirmationtime90roc  \
# Date
# 2020-01-01               -28.439             0.289                 28.514
# 2020-01-02               -20.584             0.254                 13.400
# 2020-01-03                -8.345             0.221                 -1.242
# 2020-01-04                -8.998             0.219                 -1.842
# 2020-01-05               -21.005             0.222                 -1.911
# ...                          ...               ...                    ...
# 2021-05-27                10.671             0.224                  1.821
# 2021-05-28                 6.561             0.223                  0.402
# 2021-05-29                22.244             0.223                  0.000
# 2021-05-30                17.438             0.224                  0.919
# 2021-05-31                10.937             0.224                  1.977
#
#             difficulty90roc  fee_to_reward90rocUSD  fee_to_rewardUSD  \
# ...

# %%
eth_test_set
# Out:
#             activeaddresses90roc  confirmationtime  confirmationtime90roc  \
# Date
# 2021-06-01                10.170             0.222                 -1.081
# 2021-06-02                 7.206             0.221                  0.154
# 2021-06-03                22.337             0.225                  1.905
# 2021-06-04                13.902             0.221                  0.675
# 2021-06-05                 9.320             0.224                  0.668
# ...                          ...               ...                    ...
# 2022-11-25                -1.334             0.201                -12.856
# 2022-11-26                -6.811             0.201                -12.851
# 2022-11-27               -13.483             0.201                -11.622
# 2022-11-28                 8.872             0.201                -13.436
# 2022-11-29                 0.660             0.201                -12.612
#
#             difficulty90roc  fee_to_reward90rocUSD  fee_to_rewardUSD  \
# ...

# %% [markdown]
# ### Litecoin

# %%
regs = pd.read_csv("../Data/train_ltc_selected_features.csv")
ltc = pd.read_csv("../Data/litecoin_Data.csv")
for i in range(len(ltc['Date'])):
    ltc['Date'][i]  =  datetime.strptime(ltc['Date'][i], '%Y/%m/%d')

ltc = ltc.set_index("Date")
ltcData = ltc[regs.columns]
ltc_val_set = ltcData["2020-01-01":"2021-05-31"]
ltc_test_set = ltcData["2021-06-01":"2023-11-01"]
# Out:
# /tmp/ipykernel_2919587/4139997580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ltc['Date'][i]  =  datetime.strptime(ltc['Date'][i], '%Y/%m/%d')

# %%
ltc_val_set
# Out:
#             activeaddresses30std  activeaddresses30var  activeaddresses7trx  \
# Date
# 2020-01-01                 38099             362877139                2.580
# 2020-01-02                 37283             347497290                1.294
# 2020-01-03                 37376             349244757                0.053
# 2020-01-04                 37655             354469998               -1.094
# 2020-01-05                 37857             358285053               -1.992
# ...                          ...                   ...                  ...
# 2021-05-27                 57173             817182475               -0.329
# 2021-05-28                 58356             851344377               -0.638
# 2021-05-29                 59854             895627191               -0.945
# 2021-05-30                 60356             910706991               -1.100
# 2021-05-31                 61863             956767811               -1.264
#
# ...

# %%
ltc_test_set
# Out:
#             activeaddresses30std  activeaddresses30var  activeaddresses7trx  \
# Date
# 2021-06-01                 62061             962902802               -1.296
# 2021-06-02                 63131             996389554               -1.272
# 2021-06-03                 62781             985361201               -1.016
# 2021-06-04                 61845             956211823               -0.681
# 2021-06-05                 62186             966772330               -0.541
# ...                          ...                   ...                  ...
# 2022-11-24                 55298             764459612               -0.329
# 2022-11-25                 55854             779921846               -0.097
# 2022-11-26                 55376             766634614               -0.101
# 2022-11-27                 55508             770273876               -0.228
# 2022-11-28                 54692             747797946               -0.210
#
# ...

# %%
btc_test_set
# Out:
#             difficulty14mom  difficulty30mom  difficulty3rsi  difficulty90mom  \
# Date
# 2021-06-01    -3.998757e+12     4.388848e+11           0.133    -6.764043e+11
# 2021-06-02    -3.998757e+12     4.388848e+11           0.133    -6.764043e+11
# 2021-06-03    -3.998757e+12     4.388848e+11           0.133    -6.764043e+11
# 2021-06-04    -3.998757e+12     4.388848e+11           0.133    -4.259551e+11
# 2021-06-05    -3.998757e+12     4.388848e+11           0.133    -4.005472e+11
# ...                     ...              ...             ...              ...
# 2022-11-24     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-25     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-26     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-27     1.882952e+11     1.148115e+11          99.860     8.598887e+12
# 2022-11-28     1.882952e+11     1.148115e+11          99.860     8.598887e+12
#
# ...

# %%
eth_test_set
# Out:
#             activeaddresses90roc  confirmationtime  confirmationtime90roc  \
# Date
# 2021-06-01                10.170             0.222                 -1.081
# 2021-06-02                 7.206             0.221                  0.154
# 2021-06-03                22.337             0.225                  1.905
# 2021-06-04                13.902             0.221                  0.675
# 2021-06-05                 9.320             0.224                  0.668
# ...                          ...               ...                    ...
# 2022-11-25                -1.334             0.201                -12.856
# 2022-11-26                -6.811             0.201                -12.851
# 2022-11-27               -13.483             0.201                -11.622
# 2022-11-28                 8.872             0.201                -13.436
# 2022-11-29                 0.660             0.201                -12.612
#
#             difficulty90roc  fee_to_reward90rocUSD  fee_to_rewardUSD  \
# ...

# %%
btc_val_set.to_csv('btc_val_set.csv')
btc_test_set.to_csv('btc_test_set.csv')
ltc_val_set.to_csv('ltc_val_set.csv')
ltc_test_set.to_csv('ltc_test_set.csv')

# %%
eth_val_set.to_csv('eth_val_set.csv')
eth_test_set.to_csv('eth_test_set.csv')

# %%
test_data = pd.concat([btc_test_set['priceUSD'], eth_test_set['priceUSD'], ltc_test_set['priceUSD']], axis=1)
test_data.columns = ['btc', 'eth', 'ltc']

# %%
btc_test_set['priceUSD']
# Out:
# Date
# 2021-06-01    36599.0
# 2021-06-02    37295.0
# 2021-06-03    38539.0
# 2021-06-04    37117.0
# 2021-06-05    36607.0
#                ...
# 2022-11-24    16604.0
# 2022-11-25    16495.0
# 2022-11-26    16561.0
# 2022-11-27    16542.0
# 2022-11-28    16214.0
# Name: priceUSD, Length: 546, dtype: float64

# %%
test_data
# Out:
#                 btc     eth      ltc
# Date
# 2021-06-01  36599.0  2612.0  182.100
# 2021-06-02  37295.0  2693.0  184.982
# 2021-06-03  38539.0  2799.0  190.269
# 2021-06-04  37117.0  2684.0  178.475
# 2021-06-05  36607.0  2690.0  177.253
# ...             ...     ...      ...
# 2022-11-25  16495.0  1190.0   75.830
# 2022-11-26  16561.0  1215.0   76.777
# 2022-11-27  16542.0  1215.0   76.865
# 2022-11-28  16214.0  1172.0   72.672
# 2022-11-29      NaN  1206.0      NaN
#
# [547 rows x 3 columns]

# %%
test_data.to_csv('../Data/test_set_priceUSD.csv')
